# %% [markdown]
# # TOPIC: Python, OpenCV- Image processing and transforms

# %% [markdown]
# ## Group Members
# <ol>
#     <li> ODHIAMBO KEVIN OBUYA;
#     <li> OTIENO ROWLAND ODHIAMBO;
#     <li> SAMBA BRIAN OLUOCH;
#     <li> OCHARO OBARE MARTIN;
# <ol>

# %% [markdown]
# # Outline <a class="anchor" id="0">
#
#
# ## Geometric Transformations
#
# 1. [Scaling](#1)
#   1. [Preserve Aspect Ratio](#1.1)
#     1. [Downscaling](#1.1.1)
#     1. [Upscaling](#1.1.2)
#   1. [Do not preserve Aspect Ratio](#1.2)
#     1. [Resize only width](#1.2.1)
#     1. [Resize only height](#1.2.2)
#   1. [Resize to specific width and height](#1.3)
# 1. [Cropping](#2)
# 1. [Rotating](#3)

# %% [markdown]
# ## 1. SCALING <a class="anchor" id="1">
# [Table of Contents](#0)
# - operation increases/reduces(resize) size of an image.
# - In Scaling we discussed these categories
#   - Preserve Aspect Ratio (height to width ratio of image is preserved)
#   - Do not preserve Aspect Ratio, resize only width or height
#   - Resize to specific width and height

# %% [markdown]
# ### 1.1 Preserve Aspect Ratio <a class="anchor" id="1.1">

# %% [markdown]
# #### 1.1.1 Downscaling <a class="anchor" id="1.1.1">
# [Table of Contents](#0)

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
 
img = cv2.imread('Mapengo_emoji.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (1080, 945, 3)
# Resized Dimensions :  (648, 567, 3)

# %% [markdown]
# #### 1.1.2 Upscaling <a class="anchor" id="1.1.2">
# [Table of Contents](#0)

# %%
import cv2
 
img = cv2.imread('Mapengo_emoji.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
scale_percent = 220 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (1080, 945, 3)
# Resized Dimensions :  (2376, 2079, 3)

# %% [markdown]
# ### 1.2 Do not preserve Aspect Ratio <a class="anchor" id="1.2">
#
# #### 1.2.1 Resize only width <a class="anchor" id="1.2.1">
#
# [Table of Contents](#0)

# %%
import cv2
 
img = cv2.imread('Mapengo_emoji.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
width = 440
height = img.shape[0] # keep original height
dim = (width, height)
 
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (1080, 945, 3)
# Resized Dimensions :  (1080, 440, 3)

# %% [markdown]
# #### 1.2.1 Resize only height <a class="anchor" id="1.2.2">
#
# [Table of Contents](#0)

# %%
import cv2
 
img = cv2.imread('Mapengo_emoji.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
width = img.shape[1] # keep original width
height = 440
dim = (width, height)
 
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (1080, 945, 3)
# Resized Dimensions :  (440, 945, 3)

# %% [markdown]
# ### 1.3 Resize to specific width and height <a class="anchor" id="1.3">
#
# [Table of Contents](#0)

# %%
import cv2
 
img = cv2.imread('Mapengo_emoji.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
width = 350
height = 450
dim = (width, height)
 
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (1080, 945, 3)
# Resized Dimensions :  (450, 350, 3)

# %% [markdown]
# ## 2. Cropping <a class="anchor" id="2">
#
# [Table of Contents](#0)

# %%
#Height, y axis (501 pixels) while width x axis (750 pixels)

image= cv2.imread('Mapengo_emoji.jpg')

resized_img= image[15:500, 20:300] #image[y_start:y_end, x_start:x_end]

cv2.imshow("Resize", resized_img) #Syntax: cv2.imshow(window_name, image) #window_name: A string representing the name of the window in which image to be displayed. #image: It is the image that is to be displayed. 

cv2.waitKey(0) #waitKey(0) will display the window infinitely until any keypress, while # waitKey(1) will display a frame for 1 ms, after which display will be automatically closed
cv2.destroyAllWindows()

# %% [markdown]
# ## 3.0 Rotating <a class="anchor" id="3">
#
# [Table of Contents](#0)

# %%
import cv2

img = cv2.imread('Mapengo_emoji.jpg')

img_rotate_90_clockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
cv2.imwrite('Coronavirus-structure_90_CLOCKWISE_chs_0.png', img_rotate_90_clockwise)
# True

img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2.imwrite('Coronavirus-structure_90_counterclockwise.png', img_rotate_90_counterclockwise)
# True

img_rotate_180 = cv2.rotate(img, cv2.ROTATE_180)
cv2.imwrite('Coronavirus-structure_rotate_180.png', img_rotate_180)




cv2.imshow("1",img);
cv2.waitKey(0)
cv2.destroyAllWindows()            
cv2.imshow("2",img_rotate_90_clockwise);
cv2.waitKey(0)
cv2.destroyAllWindows()            
cv2.imshow("3",img_rotate_90_counterclockwise);
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("4",img_rotate_180);
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Histograms and Histogram Equalization

# %% [markdown]
# ### Histograms

# %% [markdown]
# <p> Histograms are used to visualize the frequency of the intensity of pixel values.
#
# <p> The left side of the histogram white indicates the darker shades of intensity while the right side are
# the brighter sides of the pixel values.
#
# <p> On the x-axis of the histogram we have the pixels (bins) while on the y-axis we have the frequency of the occurence of the pixels.

# %%
### Histogram for a grayscale image
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

img_gray = cv2.imread("C:/Users/brian.samba/Documents/Computation Intelligence/Computer Vision/Images/archive/data/apple.jpg",0)

#cv2.imshow('Gray Apple',img_gray)
#cv2.waitKey()
#cv2.destroyAllWindows()

#plt.imshow(img_gray), plt.show()
plt.imshow(cv2.cvtColor(img_gray, cv2.COLOR_BGR2RGB)), plt.show()


plt.hist(img_gray.ravel(),256,[0,256]); plt.show()

# %%
img_color = cv2.imread("C:/Users/brian.samba/Documents/Computation Intelligence/Computer Vision/Images/archive/data/apple.jpg")
color = ('b', 'g', 'r')

#cv2.imshow(img_color)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

#img_rgb = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
#plt.imshow(img_rgb), plt.show()

plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)), plt.show()

for i, col in enumerate(color):
    histr = cv2.calcHist([img_color], [i], None, [256], [0,256])
    plt.plot(histr, color = col)
    plt.xlim([0,256])

# %% [markdown]
# ### Histogram Equalization

# %% [markdown]
# <p> Histogram Equalization is a technique for adjusting image intensities to enhance contrast.
#
# <p> It accomplishes this by effectively spreading out the most frequent intensity values i.e the intensity range of the image.
#
# <p> It usually increases the global contrast of images when its usable data is represented by close contrast values, allowing areas of lower local contrast to gain a higher contrast.

# %%
img_hist = cv2.imread("C:/Users/brian.samba/Documents/Computation Intelligence/Computer Vision/Images/archive/data/apple.jpg", 0)
equ = cv2.equalizeHist(img_hist)

plt.imshow(cv2.cvtColor(img_hist, cv2.COLOR_BGR2RGB)), plt.title('original'),plt.show()
plt.imshow(cv2.cvtColor(equ, cv2.COLOR_BGR2RGB)), plt.title('equalized'), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x24e976be940>,
#  Text(0.5, 1.0, 'equalized'),
#  None)

# %%
### Calculate the histogram of the equalized histogram

hist = cv2.calcHist([equ],[0],None,[256], [0,256])
plt.plot(hist), plt.show()

#plt.hist(equ.ravel(),256,[0,256]); plt.show()
# Out:
# ([<matplotlib.lines.Line2D at 0x24e997acda0>], None)

# %% [markdown]
# ####  Adaptive histogram Equalization

# %%
img_adapt = img_hist = cv2.imread("C:/Users/brian.samba/Documents/Computation Intelligence/Computer Vision/Images/archive/data/apple.jpg", 0)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img_adapt)

plt.imshow(cv2.cvtColor(cl1, cv2.COLOR_BGR2RGB)), plt.show()

## calc the histogram for the adaptive histogram equalization method
#hist_adapt = cv2.calcHist([cl1],[0],None,[256],[0,256])
#plt.plot(hist_adapt), plt.show()

#cv2.imshow('adaptive', cl1)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# (<matplotlib.image.AxesImage at 0x24e98344b38>, None)

# %% [markdown]
# ## Image Transforms

# %% [markdown]
# <p1> Image transforms are a technique used to convert an image from one domain to another domain i.e from the time/spatial domain to the frequency domain
#
# <p1> Image transfroms do not alter the information of the original image and the operation can be reversed to obtain the original image through the use of inverse transforms
#
# <p1> Image transform operations allow us to simplify calculations and computations i.e operations which involve complex calculations in one domain can be simplified by converting the image to another domain and then transforming it back to the the original domain once the computation has been completed.
#
# <p> Another usefullness of image transfoms is that it enables the extraction of more features from the image, e.g white light can be split using a prism to obtain a spectra of colors, enabling us to know the composition of the light.

# %% [markdown]
# ### Fourier Transform

# %% [markdown]
# Fourier transform is used to find the frequency domian of an image. You can consider an image as a signal which is sampled in two directions. So taking a fourier transform in both X and Y directions gives you the frequency representation of image.
#
# For the sinusoidal signal, if the amplitude varies so fast in short time, you can say it is a high frequency signal. If it varies slowly, it is a low frequency signal.
#
# Edges and noises are high frequency contents in an image because they change drastically in images.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

file_path = "apple.jpeg"

image = cv2.imread(file_path, cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray_image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE )
gray_image = cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB)

images = [image, gray_image]
titles = ["original", "gray"]

fig=plt.figure(figsize=(100, 100))
columns = len(images)
rows = 1
for i in range(0, columns):
    fig.add_subplot(30, 30, i+1)
    plt.title(titles[i])
    plt.imshow(images[i])
plt.show()

# %% [markdown]
# You can see more whiter region at the center showing low frequency content is more.

# %%
img = cv2.imread(file_path,0)

dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# More whiter region at the center showing low frequency content is more

# %% [markdown]
# With frequency transform you can now do some operations in frequency domain, like high pass filtering and reconstruct the image, ie find inverse DFT.
#
# For that you simply remove the low frequencies by masking with a rectangular window of size 60x60. Then apply the inverse shift using np.fft.ifftshift() so that DC component again come at the top-left corner.
#
# Then find inverse FFT using np.ifft2() function. The result, again, will be a complex number. You can take its absolute value.

# %%
rows, cols = img.shape
crow,ccol = rows/2 , cols/2

# create a mask first, center square is 1, remaining all zeros
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-50:crow+50, ccol-50:ccol+50] = 1

# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-19e0a3b7f6db> in <module>
#       4 # create a mask first, center square is 1, remaining all zeros
#       5 mask = np.zeros((rows,cols,2),np.uint8)
# ----> 6 mask[crow-50:crow+50, ccol-50:ccol+50] = 1
#       7
#       8 # apply mask and inverse DFT
#
# TypeError: slice indices must be integers or None or have an __index__ method
